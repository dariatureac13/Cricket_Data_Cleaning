# %%
import pandas as pd

# %%
df = pd.read_csv('CricketTestMatchData.csv', sep =';')

# %%
df
# Out:
#                Player       Span  Mat  Inns  NO  Runs    HS    Ave     BF  \
# 0    DG Bradman (AUS)  1928-1948   52    80  10  6996   334  99.94  9800+
# 1      AC Voges (AUS)  2015-2016   20    31   7  1485  269*  61.87   2667
# 2     RG Pollock (SA)  1963-1970   23    41   4  2256   274  60.97  1707+
# 3     GA Headley (WI)  1930-1954   22    40   4  2190  270*  60.83   416+
# 4     GA Headley (WI)  1930-1954   22    40   4  2190  270*  60.83   416+
# ..                ...        ...  ...   ...  ..   ...   ...    ...    ...
# 60   KD Walters (AUS)  1965-1981   74   125  14  5357   250  48.26  8662+
# 61  GC Smith (ICC/SA)  2002-2014  117   205  13  9265   277  48.25  15525
# 62  WH Ponsford (AUS)  1924-1934   29    48   4  2122   266  48.22  3118+
# 63    SJ McCabe (AUS)  1930-1938   39    62   5  2748   232  48.21  3217+
# 64   DR Jardine (ENG)  1928-1934   22    33   6  1296   127  48.00  2110+
#
#        SR  100  50   0    4s  6s
# 0   58.60   29  13   7  626+   6
# ...

# %%
#rename Multiple Columns in a list

# %%
df = df.rename(columns = {'Mat': 'Matches','NO': 'Not_Outs', 'HS':'Highest_Inns_Score', 'BF': 'Balls_Faced', 'SR': 'Batting_Strike_Rate'})

# %%
df.head()
# Out:
#              Player       Span  Matches  Inns  Not_Outs  Runs  \
# 0  DG Bradman (AUS)  1928-1948       52    80        10  6996
# 1    AC Voges (AUS)  2015-2016       20    31         7  1485
# 2   RG Pollock (SA)  1963-1970       23    41         4  2256
# 3   GA Headley (WI)  1930-1954       22    40         4  2190
# 4   GA Headley (WI)  1930-1954       22    40         4  2190
#
#   Highest_Inns_Score    Ave Balls_Faced  Batting_Strike_Rate  100  50  0  \
# 0                334  99.94       9800+                58.60   29  13  7
# 1               269*  61.87        2667                55.68    5   4  2
# 2                274  60.97       1707+                54.48    7  11  1
# 3               270*  60.83        416+                56.00   10   5  2
# 4               270*  60.83        416+                56.00   10   5  2
#
#      4s  6s
# 0  626+   6
# 1   186   5
# 2  246+  11
# 3  104+   1
# 4  104+   1

# %%
#Check Null Values

# %%
df.isnull().any()
# Out:
# Player                 False
# Span                   False
# Matches                False
# Inns                   False
# Not_Outs               False
# Runs                   False
# Highest_Inns_Score     False
# Ave                    False
# Balls_Faced             True
# Batting_Strike_Rate     True
# 100                    False
# 50                     False
# 0                      False
# 4s                     False
# 6s                     False
# dtype: bool

# %%
df[df['Balls_Faced'].isna()==1]
# Out:
#                   Player       Span  Matches  Inns  Not_Outs  Runs  \
# 8         ED Weekes (WI)  1948-1958       48    81         5  4455
# 16       CL Walcott (WI)  1948-1960       44    74         7  3798
# 55  Hon.FS Jackson (ENG)  1893-1905       20    33         4  1415
#
#    Highest_Inns_Score    Ave Balls_Faced  Batting_Strike_Rate  100  50  0  \
# 8                 207  58.61         NaN                  NaN   15  19  6
# 16                220  56.68         NaN                  NaN   15  14  1
# 55               144*  48.79         NaN                  NaN    5   6  3
#
#       4s  6s
# 8   258+   2
# 16  107+  11
# 55   51+   0

# %%
df['Balls_Faced'] = df['Balls_Faced'].fillna('0')

# %%
df['Batting_Strike_Rate'] = df['Batting_Strike_Rate'].fillna(0)
df.isnull().any()
# Out:
# Player                 False
# Span                   False
# Matches                False
# Inns                   False
# Not_Outs               False
# Runs                   False
# Highest_Inns_Score     False
# Ave                    False
# Balls_Faced            False
# Batting_Strike_Rate    False
# 100                    False
# 50                     False
# 0                      False
# 4s                     False
# 6s                     False
# dtype: bool

# %%
df
# Out:
#                Player       Span  Matches  Inns  Not_Outs  Runs  \
# 0    DG Bradman (AUS)  1928-1948       52    80        10  6996
# 1      AC Voges (AUS)  2015-2016       20    31         7  1485
# 2     RG Pollock (SA)  1963-1970       23    41         4  2256
# 3     GA Headley (WI)  1930-1954       22    40         4  2190
# 4     GA Headley (WI)  1930-1954       22    40         4  2190
# ..                ...        ...      ...   ...       ...   ...
# 60   KD Walters (AUS)  1965-1981       74   125        14  5357
# 61  GC Smith (ICC/SA)  2002-2014      117   205        13  9265
# 62  WH Ponsford (AUS)  1924-1934       29    48         4  2122
# 63    SJ McCabe (AUS)  1930-1938       39    62         5  2748
# 64   DR Jardine (ENG)  1928-1934       22    33         6  1296
#
#    Highest_Inns_Score    Ave Balls_Faced  Batting_Strike_Rate  100  50   0  \
# 0                 334  99.94       9800+                58.60   29  13   7
# ...

# %%
df[df['Player']=='ED Weekes (WI)']
# Out:
#            Player       Span  Matches  Inns  Not_Outs  Runs  \
# 8  ED Weekes (WI)  1948-1958       48    81         5  4455
#
#   Highest_Inns_Score    Ave Balls_Faced  Batting_Strike_Rate  100  50  0  \
# 8                207  58.61           0                  0.0   15  19  6
#
#      4s 6s
# 8  258+  2

# %%
#drop duplicates

# %%
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4      True
#       ...
# 60    False
# 61    False
# 62    False
# 63    False
# 64    False
# Length: 65, dtype: bool

# %%
df[df['Player'].duplicated()==1]
# Out:
#                Player       Span  Matches  Inns  Not_Outs  Runs  \
# 4     GA Headley (WI)  1930-1954       22    40         4  2190
# 12     GS Sobers (WI)  1954-1974       93   160        21  8032
# 15     JB Hobbs (ENG)  1908-1930       61   102         7  5410
# 58  YBK Jaiswal (IND)  2023-2026       29    54         2  2535
#
#    Highest_Inns_Score    Ave Balls_Faced  Batting_Strike_Rate  100  50   0  \
# 4                270*  60.83        416+                56.00   10   5   2
# 12               365*  57.78       4063+                53.58   26  30  12
# 15                211  56.94       5363+                46.22   15  28   4
# 58               214*  48.75        3835                66.10    7  13   6
#
#       4s   6s
# 4   104+    1
# 12  593+  32+
# 15  276+    8
# 58   317   45

# %%
df[df['Player'].isin(['GA Headley (WI)', 'GS Sobers (WI)', 'JB Hobbs (ENG)', 'YBK Jaiswal (IND)'])]
# Out:
#                Player       Span  Matches  Inns  Not_Outs  Runs  \
# 3     GA Headley (WI)  1930-1954       22    40         4  2190
# 4     GA Headley (WI)  1930-1954       22    40         4  2190
# 11     GS Sobers (WI)  1954-1974       93   160        21  8032
# 12     GS Sobers (WI)  1954-1974       93   160        21  8032
# 14     JB Hobbs (ENG)  1908-1930       61   102         7  5410
# 15     JB Hobbs (ENG)  1908-1930       61   102         7  5410
# 57  YBK Jaiswal (IND)  2023-2026       29    54         2  2535
# 58  YBK Jaiswal (IND)  2023-2026       29    54         2  2535
#
#    Highest_Inns_Score    Ave Balls_Faced  Batting_Strike_Rate  100  50   0  \
# 3                270*  60.83        416+                56.00   10   5   2
# 4                270*  60.83        416+                56.00   10   5   2
# 11               365*  57.78       4063+                53.58   26  30  12
# 12               365*  57.78       4063+                53.58   26  30  12
# ...

# %%
df = df.drop_duplicates()

# %%
df[df['Player'].isin(['GA Headley (WI)', 'GS Sobers (WI)', 'JB Hobbs (ENG)', 'YBK Jaiswal (IND)'])]
# Out:
#                Player       Span  Matches  Inns  Not_Outs  Runs  \
# 3     GA Headley (WI)  1930-1954       22    40         4  2190
# 11     GS Sobers (WI)  1954-1974       93   160        21  8032
# 14     JB Hobbs (ENG)  1908-1930       61   102         7  5410
# 57  YBK Jaiswal (IND)  2023-2026       29    54         2  2535
#
#    Highest_Inns_Score    Ave Balls_Faced  Batting_Strike_Rate  100  50   0  \
# 3                270*  60.83        416+                56.00   10   5   2
# 11               365*  57.78       4063+                53.58   26  30  12
# 14                211  56.94       5363+                46.22   15  28   4
# 57               214*  48.75        3835                66.10    7  13   6
#
#       4s   6s
# 3   104+    1
# 11  593+  32+
# 14  276+    8
# 57   317   45

# %%
# split up span into start and end date

# %%
df['Span'].str.split(pat = '-')
# Out:
# 0     [1928, 1948]
# 1     [2015, 2016]
# 2     [1963, 1970]
# 3     [1930, 1954]
# 5     [1924, 1935]
#           ...
# 60    [1965, 1981]
# 61    [2002, 2014]
# 62    [1924, 1934]
# 63    [1930, 1938]
# 64    [1928, 1934]
# Name: Span, Length: 61, dtype: object

# %%
df['Rookie_Year'] = df['Span'].str.split(pat = '-').str[0]
# Out:
# C:\Users\DariaTureac\AppData\Local\Temp\ipykernel_16464\3648638022.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Rookie_Year'] = df['Span'].str.split(pat = '-').str[0]

# %%
df['Final_Year'] = df['Span'].str.split(pat = '-').str[1]
# Out:
# C:\Users\DariaTureac\AppData\Local\Temp\ipykernel_16464\3090471237.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Final_Year'] = df['Span'].str.split(pat = '-').str[1]

# %%
df
# Out:
#                Player       Span  Matches  Inns  Not_Outs  Runs  \
# 0    DG Bradman (AUS)  1928-1948       52    80        10  6996
# 1      AC Voges (AUS)  2015-2016       20    31         7  1485
# 2     RG Pollock (SA)  1963-1970       23    41         4  2256
# 3     GA Headley (WI)  1930-1954       22    40         4  2190
# 5   H Sutcliffe (ENG)  1924-1935       54    84         9  4555
# ..                ...        ...      ...   ...       ...   ...
# 60   KD Walters (AUS)  1965-1981       74   125        14  5357
# 61  GC Smith (ICC/SA)  2002-2014      117   205        13  9265
# 62  WH Ponsford (AUS)  1924-1934       29    48         4  2122
# 63    SJ McCabe (AUS)  1930-1938       39    62         5  2748
# 64   DR Jardine (ENG)  1928-1934       22    33         6  1296
#
#    Highest_Inns_Score    Ave Balls_Faced  Batting_Strike_Rate  100  50   0  \
# 0                 334  99.94       9800+                58.60   29  13   7
# ...

# %%
# drop Span column

# %%
df = df.drop(['Span'], axis =1)

# %%
df.head()
# Out:
#               Player  Matches  Inns  Not_Outs  Runs Highest_Inns_Score    Ave  \
# 0   DG Bradman (AUS)       52    80        10  6996                334  99.94
# 1     AC Voges (AUS)       20    31         7  1485               269*  61.87
# 2    RG Pollock (SA)       23    41         4  2256                274  60.97
# 3    GA Headley (WI)       22    40         4  2190               270*  60.83
# 5  H Sutcliffe (ENG)       54    84         9  4555                194  60.73
#
#   Balls_Faced  Batting_Strike_Rate  100  50  0    4s  6s Rookie_Year  \
# 0       9800+                58.60   29  13  7  626+   6        1928
# 1        2667                55.68    5   4  2   186   5        2015
# 2       1707+                54.48    7  11  1  246+  11        1963
# 3        416+                56.00   10   5  2  104+   1        1930
# 5       6558+                34.59   16  23  2  202+   6        1924
#
#   Final_Year
# 0       1948
# 1       2016
# 2       1970
# 3       1954
# ...

# %%
#Split up the country from the player

# %%
df['Player'].str.split(pat = ' ')
# Out:
# 0      [DG, Bradman, (AUS)]
# 1        [AC, Voges, (AUS)]
# 2       [RG, Pollock, (SA)]
# 3       [GA, Headley, (WI)]
# 5     [H, Sutcliffe, (ENG)]
#               ...
# 60     [KD, Walters, (AUS)]
# 61    [GC, Smith, (ICC/SA)]
# 62    [WH, Ponsford, (AUS)]
# 63      [SJ, McCabe, (AUS)]
# 64     [DR, Jardine, (ENG)]
# Name: Player, Length: 61, dtype: object

# %%
df['Country'] = df['Player'].str.split(pat = ' ').str[-1].str.strip('()')

# %%
df['Player'] = df['Player'].str.split(pat = ' ').str[0] + ' ' + df['Player'].str.split(pat = ' ').str[1]

# %%
df
# Out:
#          Player  Matches  Inns  Not_Outs  Runs Highest_Inns_Score    Ave  \
# 0    DG Bradman       52    80        10  6996                334  99.94
# 1      AC Voges       20    31         7  1485               269*  61.87
# 2    RG Pollock       23    41         4  2256                274  60.97
# 3    GA Headley       22    40         4  2190               270*  60.83
# 5   H Sutcliffe       54    84         9  4555                194  60.73
# ..          ...      ...   ...       ...   ...                ...    ...
# 60   KD Walters       74   125        14  5357                250  48.26
# 61     GC Smith      117   205        13  9265                277  48.25
# 62  WH Ponsford       29    48         4  2122                266  48.22
# 63    SJ McCabe       39    62         5  2748                232  48.21
# 64   DR Jardine       22    33         6  1296                127  48.00
#
#    Balls_Faced  Batting_Strike_Rate  100  50   0    4s  6s Rookie_Year  \
# ...

# %%
df
# Out:
#          Player  Matches  Inns  Not_Outs  Runs Highest_Inns_Score    Ave  \
# 0    DG Bradman       52    80        10  6996                334  99.94
# 1      AC Voges       20    31         7  1485               269*  61.87
# 2    RG Pollock       23    41         4  2256                274  60.97
# 3    GA Headley       22    40         4  2190               270*  60.83
# 5   H Sutcliffe       54    84         9  4555                194  60.73
# ..          ...      ...   ...       ...   ...                ...    ...
# 60   KD Walters       74   125        14  5357                250  48.26
# 61     GC Smith      117   205        13  9265                277  48.25
# 62  WH Ponsford       29    48         4  2122                266  48.22
# 63    SJ McCabe       39    62         5  2748                232  48.21
# 64   DR Jardine       22    33         6  1296                127  48.00
#
#    Balls_Faced  Batting_Strike_Rate  100  50   0    4s  6s Rookie_Year  \
# ...

# %%
# change DataTypes

# %%
df.dtypes
# Out:
# Player                  object
# Matches                  int64
# Inns                     int64
# Not_Outs                 int64
# Runs                     int64
# Highest_Inns_Score      object
# Ave                    float64
# Balls_Faced             object
# Batting_Strike_Rate    float64
# 100                      int64
# 50                       int64
# 0                        int64
# 4s                      object
# 6s                      object
# Rookie_Year             object
# Final_Year              object
# Country                 object
# dtype: object

# %%
df['Highest_Inns_Score'].str.split(pat = '*').str[0]
# Out:
# 0     334
# 1     269
# 2     274
# 3     270
# 5     194
#      ...
# 60    250
# 61    277
# 62    266
# 63    232
# 64    127
# Name: Highest_Inns_Score, Length: 61, dtype: object

# %%
df['Highest_Inns_Score'] = df['Highest_Inns_Score'].str.split(pat = '*').str[0]

# %%
df['Highest_Inns_Score'] = df['Highest_Inns_Score'].astype('int') # convereted to int

# %%
df.dtypes
# Out:
# Player                  object
# Matches                  int64
# Inns                     int64
# Not_Outs                 int64
# Runs                     int64
# Highest_Inns_Score       int64
# Ave                    float64
# Balls_Faced             object
# Batting_Strike_Rate    float64
# 100                      int64
# 50                       int64
# 0                        int64
# 4s                      object
# 6s                      object
# Rookie_Year             object
# Final_Year              object
# Country                 object
# dtype: object

# %%
df = df.astype({'Rookie_Year': 'int', 'Final_Year': 'int'})

# %%
df.dtypes
# Out:
# Player                  object
# Matches                  int64
# Inns                     int64
# Not_Outs                 int64
# Runs                     int64
# Highest_Inns_Score       int64
# Ave                    float64
# Balls_Faced             object
# Batting_Strike_Rate    float64
# 100                      int64
# 50                       int64
# 0                        int64
# 4s                      object
# 6s                      object
# Rookie_Year              int64
# Final_Year               int64
# Country                 object
# dtype: object

# %%
df.head()
# Out:
#         Player  Matches  Inns  Not_Outs  Runs  Highest_Inns_Score    Ave  \
# 0   DG Bradman       52    80        10  6996                 334  99.94
# 1     AC Voges       20    31         7  1485                 269  61.87
# 2   RG Pollock       23    41         4  2256                 274  60.97
# 3   GA Headley       22    40         4  2190                 270  60.83
# 5  H Sutcliffe       54    84         9  4555                 194  60.73
#
#   Balls_Faced  Batting_Strike_Rate  100  50  0    4s  6s  Rookie_Year  \
# 0       9800+                58.60   29  13  7  626+   6         1928
# 1        2667                55.68    5   4  2   186   5         2015
# 2       1707+                54.48    7  11  1  246+  11         1963
# 3        416+                56.00   10   5  2  104+   1         1930
# 5       6558+                34.59   16  23  2  202+   6         1924
#
#    Final_Year Country
# 0        1948     AUS
# 1        2016     AUS
# 2        1970      SA
# ...

# %%
df['Balls_Faced'] = df['Balls_Faced'].str.split(pat = '+').str[0]

# %%
df['Balls_Faced'] = df['Balls_Faced'].astype('int')

# %%
df.isnull().any()
# Out:
# Player                 False
# Matches                False
# Inns                   False
# Not_Outs               False
# Runs                   False
# Highest_Inns_Score     False
# Ave                    False
# Balls_Faced            False
# Batting_Strike_Rate    False
# 100                    False
# 50                     False
# 0                      False
# 4s                     False
# 6s                     False
# Rookie_Year            False
# Final_Year             False
# Country                False
# dtype: bool

# %%
df[df['Balls_Faced'].isna()==1]
# Out:
# Empty DataFrame
# Columns: [Player, Matches, Inns, Not_Outs, Runs, Highest_Inns_Score, Ave, Balls_Faced, Batting_Strike_Rate, 100, 50, 0, 4s, 6s, Rookie_Year, Final_Year, Country]
# Index: []

# %%
pd.set_option('display.max_rows', None)

# %%
df
# Out:
#                       Player  Matches  Inns  Not_Outs   Runs  \
# 0                 DG Bradman       52    80        10   6996
# 1                   AC Voges       20    31         7   1485
# 2                 RG Pollock       23    41         4   2256
# 3                 GA Headley       22    40         4   2190
# 5                H Sutcliffe       54    84         9   4555
# 6                  E Paynter       20    31         5   1540
# 7              KF Barrington       82   131        15   6806
# 8                  ED Weekes       48    81         5   4455
# 9                 WR Hammond       85   140        16   7249
# 10               PHKD Mendis       16    28         3   1453
# 11                 GS Sobers       93   160        21   8032
# 13             KC Sangakkara      134   233        17  12400
# 14                  JB Hobbs       61   102         7   5410
# 16                CL Walcott       44    74         7   3798
# ...

# %%
df.isnull().any()
# Out:
# Player                 False
# Matches                False
# Inns                   False
# Not_Outs               False
# Runs                   False
# Highest_Inns_Score     False
# Ave                    False
# Balls_Faced            False
# Batting_Strike_Rate    False
# 100                    False
# 50                     False
# 0                      False
# 4s                     False
# 6s                     False
# Rookie_Year            False
# Final_Year             False
# Country                False
# dtype: bool

# %%
df.dtypes
# Out:
# Player                  object
# Matches                  int64
# Inns                     int64
# Not_Outs                 int64
# Runs                     int64
# Highest_Inns_Score       int64
# Ave                    float64
# Balls_Faced              int64
# Batting_Strike_Rate    float64
# 100                      int64
# 50                       int64
# 0                        int64
# 4s                      object
# 6s                      object
# Rookie_Year              int64
# Final_Year               int64
# Country                 object
# dtype: object

# %%
df['4s'] = df['4s'].str.split(pat = '+').str[0]

# %%
df['4s'] = df['4s'].astype('int')

# %%
df['6s'] = df['6s'].str.split(pat = '+').str[0]

# %%
df['6s'] = df['6s'].astype('int')

# %%
df.dtypes
# Out:
# Player                  object
# Matches                  int64
# Inns                     int64
# Not_Outs                 int64
# Runs                     int64
# Highest_Inns_Score       int64
# Ave                    float64
# Balls_Faced              int64
# Batting_Strike_Rate    float64
# 100                      int64
# 50                       int64
# 0                        int64
# 4s                       int64
# 6s                       int64
# Rookie_Year              int64
# Final_Year               int64
# Country                 object
# dtype: object

# %%
# Build out Career_Length Column

# %%
df['Career_Length'] = df['Final_Year']-df['Rookie_Year']

# %%
df
# Out:
#                       Player  Matches  Inns  Not_Outs   Runs  \
# 0                 DG Bradman       52    80        10   6996
# 1                   AC Voges       20    31         7   1485
# 2                 RG Pollock       23    41         4   2256
# 3                 GA Headley       22    40         4   2190
# 5                H Sutcliffe       54    84         9   4555
# 6                  E Paynter       20    31         5   1540
# 7              KF Barrington       82   131        15   6806
# 8                  ED Weekes       48    81         5   4455
# 9                 WR Hammond       85   140        16   7249
# 10               PHKD Mendis       16    28         3   1453
# 11                 GS Sobers       93   160        21   8032
# 13             KC Sangakkara      134   233        17  12400
# 14                  JB Hobbs       61   102         7   5410
# 16                CL Walcott       44    74         7   3798
# ...

# %%
# Calculations with the dataframe

# %%
# Question 1 -> Cricketers in this DF what is the Average Career Length

# %%
df['Career_Length'].mean()
# Out:
# np.float64(13.278688524590164)

# %%
# Question 2 -> AVG Batting_Strike_Rate for cricketers who played over 10 years

# %%
df[df['Career_Length'] > 10]['Batting_Strike_Rate'].mean()
# Out:
# np.float64(47.8153488372093)

# %%
# Question 3 -> find number of cricketers who played before 1960

# %%
df[df['Rookie_Year'] < 1960]['Player'].count()
# Out:
# np.int64(23)

# %%
# Question 4 -> Max Highest Inns Score by country

# %%
df.groupby('Country')['Highest_Inns_Score'].max().to_frame('HighInnCountry').reset_index().sort_values('HighInnCountry', ascending=False)
# Out:
#     Country  HighInnCountry
# 5    ICC/WI             400
# 0       AUS             380
# 10       SL             374
# 11       WI             365
# 1       ENG             364
# 3   ICC/PAK             329
# 2   ICC/IND             319
# 8       PAK             313
# 9        SA             278
# 4    ICC/SA             277
# 7        NZ             251
# 6       IND             248
# 12      ZIM             232

# %%
# Question 5 -> Hundreeds, Fifties, ducks (0) AVG by country

# %%
df.groupby('Country')[['100','50','0']].mean()
# Out:
#                100         50          0
# Country
# AUS      21.600000  29.133333   8.933333
# ENG      13.615385  22.153846   4.846154
# ICC/IND  29.500000  47.500000  12.000000
# ICC/PAK  25.000000  46.000000  15.000000
# ICC/SA   36.000000  48.000000  13.500000
# ICC/WI   34.000000  48.000000  17.000000
# IND      24.000000  32.250000   8.750000
# NZ       33.000000  38.000000  12.000000
# PAK      21.250000  28.000000   9.500000
# SA        9.800000  20.200000   3.400000
# SL       22.750000  34.500000   9.500000
# WI       16.625000  25.625000   7.250000
# ZIM      12.000000  27.000000   5.000000
